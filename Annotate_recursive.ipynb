# %%
# loading the metadata
# %load_ext autoreload
# %autoreload 2

#cp /home/guhennec/scratch/2021_Cini/TopologicalAnalysis_Cini/data/save_link_data_2018_08_02.pkl morphograph_update.pkl
from annotation_loop import main, get_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
embeddings = get_data(size=10000)
# Out:
# /scratch/students/schaerf/Cini_TDA/annotation_loop.py:11: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(data_dir + 'dedup_data.csv').sample(size) #'full_data.csv').drop(columns=['Unnamed: 0', 'level_0'])
# (329480, 3)

# %%
embeddings = embeddings[:,:2]
embeddings
# Out:
# array([['9876a372404b4b07ba914caad62773d0',
#         array([0.00757632, 0.02504339, 0.01431948, ..., 0.0050136 , 0.01454739,
#        0.02595678], dtype=float32)],
#        ['d0904634d0c4443fa8f8b4f6b8140e48',
#         array([0.00054445, 0.03886459, 0.01068235, ..., 0.00112533, 0.00943272,
#        0.0037311 ], dtype=float32)],
#        ['374c257854be40a29431e67f30373441',
#         array([0.00832958, 0.03940097, 0.01590364, ..., 0.00253626, 0.01853185,
#        0.03385183], dtype=float32)],
#        ...,
#        ['ad05a614b8a9433cbd34344bd31d9ab8',
#         array([0.        , 0.00583586, 0.00335811, ..., 0.0087772 , 0.01927482,
#        0.01870785], dtype=float32)],
#        ['b5c35de2bb9341598cc16d6c9709ef6d',
#         array([0.        , 0.03072179, 0.00471209, ..., 0.00061183, 0.        ,
#        0.02443652], dtype=float32)],
#        ['4bcaff1803a1426a8fb9978c6104a2cc',
#         array([0.00680892, 0.0283148 , 0.00188492, ..., 0.00528946, 0.01481058,
#        0.04154754], dtype=float32)]], dtype=object)

# %%
main(embeddings=embeddings, embds=True)
# Out:
# /scratch/students/schaerf/Cini_TDA/annotation_loop.py:24: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(data_dir + 'dedup_data.csv').drop(columns=['Unnamed: 0', 'level_0'])#'full_data.csv')
#                                    uid                              img1  \
# 7968  74c3b2b75bda4e3db3565aa172100f40  c5839e5220e5419e92d878396b0c04bb
# 9935  869c5c8767c7482eb89260852435404a  ef25d7d6549547b59945a61ae6849d3d
# 0     06d37d5e06ce4b40aa4d2d860abf790b  06d37d5e06ce4b40b583c1cb6d7f68b2
#
#                                   img2      type  \
# 7968  3547eedf41a24f6b832e9bb5ce372a36  POSITIVE
# 9935  8bb6bbde25084e139c4ddacfcc68e121  POSITIVE
# 0     f128507133584da8aa4d2d860abf790b  POSITIVE
#
#                              annotated
# 7968  2018-05-07 08:28:11.533367+00:00
# 9935  2018-07-16 09:50:55.272366+00:00
# 0                  05-04-2022_17:16:51
# (2, 5) (3, 5)
