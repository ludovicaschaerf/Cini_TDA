# %%
# loading the metadata
# %load_ext autoreload
# %autoreload 2

#cp /home/guhennec/scratch/2021_Cini/TopologicalAnalysis_Cini/data/save_link_data_2018_08_02.pkl morphograph_update.pkl
from annotation_loop import main

# %%
main()
# Out:
#                                     img1  ...                         annotated
# 120645  50042ca647f44063a06da15b32942fdb  ...  2018-08-01 13:07:07.673118+00:00
# 120654  1dea6fca833d455a9a0e82affd0e6f14  ...  2018-08-01 22:39:04.189838+00:00
# 0       6eee7bd1bf30411bbe5896f11055339e  ...               01-04-2022_12:43:29
# 0       5c150f9c3af149eb9a83c8391190566d  ...               01-04-2022_14:05:27
# 1       5c150f9c3af149eb9a83c8391190566d  ...               01-04-2022_14:05:27
#
# [5 rows x 3 columns]
# (2602, 5) (2602, 5)
