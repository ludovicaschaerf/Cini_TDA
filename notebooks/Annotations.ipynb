# %% [markdown]
# ### Annotations
#
# Notebook version of the web annotation tool

# %%
# loading the metadata
# %load_ext autoreload
# %autoreload 2
import sys

sys.path.insert(0, "../web_annotation/")

#cp /home/guhennec/scratch/2021_Cini/TopologicalAnalysis_Cini/data/save_link_data_2018_08_02.pkl morphograph_update.pkl

from annotation_tools import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
embeddings, data, tree, reverse_map, uid2path = setup(size=10000)
# Out:
# /scratch/students/schaerf/Cini_TDA/notebooks/../web_annotation/annotation_tools.py:14: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(data_dir + 'dedup_data.csv').drop(columns=['Unnamed: 0', 'level_0']).sample(size) #'full_data.csv').drop(columns=['Unnamed: 0', 'level_0'])

# %%
main(embeddings=embeddings, data=data, tree=tree, reverse_map=reverse_map, embds=True, uid2path=uid2path)
# Out:
# Empty DataFrame
# Columns: [uid, img1, img2, type, annotated]
# Index: []
# (0, 5) (0, 5)
